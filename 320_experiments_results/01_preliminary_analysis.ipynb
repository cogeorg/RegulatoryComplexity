# %%
import pandas as pd

submissions = pd.read_csv("submissions.csv")

# %%
submissions.head()
# Out:
#    id_submission  question  regulation   user    answer  correct answer  \
# 0            200         1           1  71479  Practice            38.0
# 1            201         2          19  71479      35.0            55.0
# 2            202         3          13  71479      34.0            22.0
# 3            203         4          38  71479      62.0            61.0
# 4            204         5          17  71479      55.0            60.0
#
#    score student id      time taken
# 0      0      71479  0:04:08.098486
# 1      0      71479  0:01:14.773633
# 2      0      71479  0:01:30.411546
# 3      0      71479  0:00:36.346351
# 4      0      71479  0:00:43.668784

# %%
submissions.drop(['id_submission'], axis=1)
# Out:
#      question  regulation    user    answer  correct answer  score student id  \
# 0           1           1   71479  Practice            38.0      0      71479
# 1           2          19   71479      35.0            55.0      0      71479
# 2           3          13   71479      34.0            22.0      0      71479
# 3           4          38   71479      62.0            61.0      0      71479
# 4           5          17   71479      55.0            60.0      0      71479
# ..        ...         ...     ...       ...             ...    ...        ...
# 608         9          36  S63722      30.0            30.0      8     S63722
# 609        10          13  S63722      22.0            22.0      9     S63722
# 610         9          24  S62720      46.0            46.0      5     S62720
# 611        10          34  S62720       1.0             1.0      6     S62720
# 612        10          34  S62720       1.0             1.0      7     S62720
#
#          time taken
# ...

# %%
display(submissions.dtypes)
# Out:
# id_submission       int64
# question            int64
# regulation          int64
# user               object
# answer             object
# correct answer    float64
# score               int64
# student id         object
# time taken         object
# dtype: object

# %%
foo = submissions.drop(submissions[(submissions.answer == "Practice")].index)

# %%
foo.head()
# Out:
#    id_submission  question  regulation   user answer  correct answer  score  \
# 1            201         2          19  71479   35.0            55.0      0
# 2            202         3          13  71479   34.0            22.0      0
# 3            203         4          38  71479   62.0            61.0      0
# 4            204         5          17  71479   55.0            60.0      0
# 5            205         6          31  71479   34.0            32.0      0
#
#   student id      time taken
# 1      71479  0:01:14.773633
# 2      71479  0:01:30.411546
# 3      71479  0:00:36.346351
# 4      71479  0:00:43.668784
# 5      71479  0:01:14.430520
